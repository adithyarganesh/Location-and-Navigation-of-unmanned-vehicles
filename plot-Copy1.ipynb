# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
n, radii = 50, [6, 17]
theta = np.linspace(0, 2*np.pi, n, endpoint=True)
xs = np.outer(radii, np.cos(theta))
ys = np.outer(radii, np.sin(theta))

# in order to have a closed area, the circles
# should be traversed in opposite directions
xs[1,:] = xs[1,::-1]
ys[1,:] = ys[1,::-1]

ax = plt.subplot(111, aspect='equal')
ax.fill(np.ravel(xs), np.ravel(ys))
plt.show()

# %%
# in ipython notebook, enable inline plotting with:
# %pylab inline --no-import-all
import matplotlib.pyplot as plt

# create some circles
circle1 = plt.Circle((-.5,0), 1, color='r', alpha=.2)
c = plt.Circle((-.5,0), .5, color='white', alpha=.5)
circle2 = plt.Circle(( .5,0), 1, color='b', alpha=.2)

# add them to the plot (bad form to use ;, but saving space)
# and control the display a bit
ax = plt.gca()
ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(c)
ax.set_xlim(-2, 2); ax.set_ylim(-2, 2)
ax.set_aspect('equal')

# display it
plt.plot()
plt.show()

# %%
circle1 = plt.Circle((0, 5.5), 9, color='r')
circle2 = plt.Circle((0,11), 17, color='blue')
circle3 = plt.Circle((1, 16.5), 9, color='g', clip_on=False)

fig, ax = plt.subplots() # note we must use plt.subplots, not plt.subplot
# (or if you have an existing figure)
# fig = plt.gcf()
# ax = fig.gca()

ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)

plt.show()

# %%
#implementation

# %%
import pylab
axes = pylab.axes()
circle1 = pylab.Circle((5.5,0), radius=17, alpha=.4)
circle1a = pylab.Circle((5.5,0), radius=6,color = "w", alpha=.2)
circle2 = pylab.Circle((11,0), radius=9, alpha=.4)
circle3 = pylab.Circle((16.5,0), radius=17, alpha=.4)
circle3a = pylab.Circle((16.5,0), radius=6,color = "w", alpha=.2)
circle4 = pylab.Circle((22,5.5), radius=17, alpha=.4)
circle4a = pylab.Circle((22,5.5), radius=6,color = "w", alpha=.2)
circle5 = pylab.Circle((22,11), radius=9, alpha=.4)
circle6 = pylab.Circle((22,16.5), radius=17, alpha=.4)
circle5a = pylab.Circle((22,16.5), radius=6,color = "w", alpha=.2,clip_on=True)
circle7 = pylab.Circle((16.5,22), radius=17, alpha=.4)
circle6a = pylab.Circle((16.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle8 = pylab.Circle((11,22), radius=9, alpha=.4)
circle9 = pylab.Circle((5.5,22), radius=17, alpha=.4)
circle7a = pylab.Circle((5.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle10 = pylab.Circle((0,16.5), radius=17, alpha=.4)
circle8a = pylab.Circle((0,16.5), radius=6,color = "w", alpha=.2,clip_on=True)
circle11 = pylab.Circle((0,11), radius=9, alpha=.4)
circle12 = pylab.Circle((0,5.5), radius=17, alpha=.4)
circle9a = pylab.Circle((0,5.5), radius=6,color = "w", alpha=.2,clip_on=True)
line = plt.Line2D((0,0), (0,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((22,22), (22,0), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (22,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (0,0), lw=1.0)
plt.gca().add_line(line)

axes.add_patch(circle1)
axes.add_patch(circle2)
axes.add_patch(circle3)
axes.add_patch(circle4)
axes.add_patch(circle5)
axes.add_patch(circle6)
axes.add_patch(circle7)
axes.add_patch(circle8)
axes.add_patch(circle9)
axes.add_patch(circle10)
axes.add_patch(circle11)
axes.add_patch(circle12)
axes.add_patch(circle1a)
axes.add_patch(circle4a)
axes.add_patch(circle3a)
axes.add_patch(circle5a)
axes.add_patch(circle6a)
axes.add_patch(circle7a)
axes.add_patch(circle8a)
axes.add_patch(circle9a)

pylab.axis('scaled')
# fig1 = plt.figure()
# ax1 = fig1.add_subplot( 111,aspect='equal')
# ax1.add_patch(
#     patches.Rectangle(
#         (0,0),   # (x,y)
#         22,          # width
#         22,          # height
#     )
# )
pylab.show()
########################################################################################
import pylab
axes = pylab.axes()
circle1 = pylab.Circle((5.5,0), radius=17, alpha=.4)
circle1a = pylab.Circle((5.5,0), radius=6,color = "w", alpha=.2)
circle2 = pylab.Circle((11,0), radius=9, alpha=.4)
circle3 = pylab.Circle((16.5,0), radius=17, alpha=.4)
circle3a = pylab.Circle((16.5,0), radius=6,color = "w", alpha=.2)
circle4 = pylab.Circle((22,5.5), radius=9, alpha=.4)
circle4a = pylab.Circle((22,11), radius=6,color = "w", alpha=.2)
circle5 = pylab.Circle((22,11), radius=17, alpha=.4)
circle6 = pylab.Circle((22,16.5), radius=9, alpha=.4)
circle5a = pylab.Circle((16.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle7 = pylab.Circle((16.5,22), radius=17, alpha=.4)
circle8 = pylab.Circle((11,22), radius=9, alpha=.4)
circle9 = pylab.Circle((5.5,22), radius=17, alpha=.4)
circle7a = pylab.Circle((5.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle10 = pylab.Circle((0,16.5), radius=9, alpha=.4)
circle8a = pylab.Circle((0,11), radius=6,color = "w", alpha=.2,clip_on=True)
circle11 = pylab.Circle((0,11), radius=17, alpha=.4)
circle12 = pylab.Circle((0,5.5), radius=9, alpha=.4)
line = plt.Line2D((0,0), (0,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((22,22), (22,0), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (22,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (0,0), lw=1.0)
plt.gca().add_line(line)

axes.add_patch(circle1)
axes.add_patch(circle2)
axes.add_patch(circle3)
axes.add_patch(circle4)
axes.add_patch(circle5)
axes.add_patch(circle6)
axes.add_patch(circle7)
axes.add_patch(circle8)
axes.add_patch(circle9)
axes.add_patch(circle10)
axes.add_patch(circle11)
axes.add_patch(circle12)
axes.add_patch(circle1a)
axes.add_patch(circle4a)
axes.add_patch(circle3a)
axes.add_patch(circle5a)
axes.add_patch(circle7a)
axes.add_patch(circle8a)

pylab.axis('scaled')
# fig1 = plt.figure()
# ax1 = fig1.add_subplot( 111,aspect='equal')
# ax1.add_patch(
#     patches.Rectangle(
#         (0,0),   # (x,y)
#         22,          # width
#         22,          # height
#     )
# )
pylab.show()

# %%
import pylab
import matplotlib.pyplot as plt
axes = pylab.axes()
circle1 = pylab.Circle((5.5,0), radius=16, alpha=.4)
circle1a = pylab.Circle((5.5,0), radius=6,color = "w", alpha=.2)
circle2 = pylab.Circle((11,0), radius=8, alpha=.4)
circle3 = pylab.Circle((16.5,0), radius=16, alpha=.4)
circle3a = pylab.Circle((16.5,0), radius=6,color = "w", alpha=.2)
circle4 = pylab.Circle((22,5.5), radius=16, alpha=.4)
circle4a = pylab.Circle((22,5.5), radius=6,color = "w", alpha=.2)
circle5 = pylab.Circle((22,11), radius=8, alpha=.4)
circle6 = pylab.Circle((22,16.5), radius=16, alpha=.4)
circle5a = pylab.Circle((22,16.5), radius=6,color = "w", alpha=.2,clip_on=True)
circle7 = pylab.Circle((16.5,22), radius=16, alpha=.4)
circle6a = pylab.Circle((16.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle8 = pylab.Circle((11,22), radius=8, alpha=.4)
circle9 = pylab.Circle((5.5,22), radius=16, alpha=.4)
circle7a = pylab.Circle((5.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle10 = pylab.Circle((0,16.5), radius=16, alpha=.4)
circle8a = pylab.Circle((0,16.5), radius=6,color = "w", alpha=.2,clip_on=True)
circle11 = pylab.Circle((0,11), radius=8, alpha=.4)
circle12 = pylab.Circle((0,5.5), radius=16, alpha=.4)
circle9a = pylab.Circle((0,5.5), radius=6,color = "w", alpha=.2,clip_on=True)
line = plt.Line2D((0,0), (0,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((22,22), (22,0), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (22,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (0,0), lw=1.0)
plt.gca().add_line(line)

axes.add_patch(circle1)
axes.add_patch(circle2)
axes.add_patch(circle3)
axes.add_patch(circle4)
axes.add_patch(circle5)
axes.add_patch(circle6)
axes.add_patch(circle7)
axes.add_patch(circle8)
axes.add_patch(circle9)
axes.add_patch(circle10)
axes.add_patch(circle11)
axes.add_patch(circle12)
axes.add_patch(circle1a)
axes.add_patch(circle4a)
axes.add_patch(circle3a)
axes.add_patch(circle5a)
axes.add_patch(circle6a)
axes.add_patch(circle7a)
axes.add_patch(circle8a)
axes.add_patch(circle9a)

pylab.axis('scaled')
# fig1 = plt.figure()
# ax1 = fig1.add_subplot( 111,aspect='equal')
# ax1.add_patch(
#     patches.Rectangle(
#         (0,0),   # (x,y)
#         22,          # width
#         22,          # height
#     )
# )
pylab.show()
########################################################################################
import pylab
axes = pylab.axes()
circle1 = pylab.Circle((5.5,0), radius=16, alpha=.4)
circle1a = pylab.Circle((5.5,0), radius=6,color = "w", alpha=.2)
circle2 = pylab.Circle((11,0), radius=8, alpha=.4)
circle3 = pylab.Circle((16.5,0), radius=16, alpha=.4)
circle3a = pylab.Circle((16.5,0), radius=6,color = "w", alpha=.2)
circle4 = pylab.Circle((22,5.5), radius=8, alpha=.4)
circle4a = pylab.Circle((22,11), radius=6,color = "w", alpha=.2)
circle5 = pylab.Circle((22,11), radius=16, alpha=.4)
circle6 = pylab.Circle((22,16.5), radius=8, alpha=.4)
circle5a = pylab.Circle((16.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle7 = pylab.Circle((16.5,22), radius=16, alpha=.4)
circle8 = pylab.Circle((11,22), radius=8, alpha=.4)
circle9 = pylab.Circle((5.5,22), radius=16, alpha=.4)
circle7a = pylab.Circle((5.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
circle10 = pylab.Circle((0,16.5), radius=8, alpha=.4)
circle8a = pylab.Circle((0,11), radius=6,color = "w", alpha=.2,clip_on=True)
circle11 = pylab.Circle((0,11), radius=16, alpha=.4)
circle12 = pylab.Circle((0,5.5), radius=8, alpha=.4)
line = plt.Line2D((0,0), (0,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((22,22), (22,0), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (22,22), lw=1.0)
plt.gca().add_line(line)
line = plt.Line2D((0,22), (0,0), lw=1.0)
plt.gca().add_line(line)

axes.add_patch(circle1)
axes.add_patch(circle2)
axes.add_patch(circle3)
axes.add_patch(circle4)
axes.add_patch(circle5)
axes.add_patch(circle6)
axes.add_patch(circle7)
axes.add_patch(circle8)
axes.add_patch(circle9)
axes.add_patch(circle10)
axes.add_patch(circle11)
axes.add_patch(circle12)
axes.add_patch(circle1a)
axes.add_patch(circle4a)
axes.add_patch(circle3a)
axes.add_patch(circle5a)
axes.add_patch(circle7a)
axes.add_patch(circle8a)

pylab.axis('scaled')
# fig1 = plt.figure()
# ax1 = fig1.add_subplot( 111,aspect='equal')
# ax1.add_patch(
#     patches.Rectangle(
#         (0,0),   # (x,y)
#         22,          # width
#         22,          # height
#     )
# )
pylab.show()

# %%
import numpy as np
gg = []
i=0
def eucl(m,n):
    circle1 = pylab.Circle((5.5,0), radius=16, alpha=.4)
    circle1a = pylab.Circle((5.5,0), radius=6,color = "w", alpha=.2)
    circle2 = pylab.Circle((11,0), radius=8, alpha=.4)
    circle3 = pylab.Circle((16.5,0), radius=16, alpha=.4)
    circle3a = pylab.Circle((16.5,0), radius=6,color = "w", alpha=.2)
    circle4 = pylab.Circle((22,5.5), radius=8, alpha=.4)
    circle4a = pylab.Circle((22,11), radius=6,color = "w", alpha=.2)
    circle5 = pylab.Circle((22,11), radius=16, alpha=.4)
    circle6 = pylab.Circle((22,16.5), radius=8, alpha=.4)
    circle5a = pylab.Circle((16.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
    circle7 = pylab.Circle((16.5,22), radius=16, alpha=.4)
    circle8 = pylab.Circle((11,22), radius=8, alpha=.4)
    circle9 = pylab.Circle((5.5,22), radius=16, alpha=.4)
    circle7a = pylab.Circle((5.5,22), radius=6,color = "w", alpha=.2,clip_on=True)
    circle10 = pylab.Circle((0,16.5), radius=8, alpha=.4)
    circle8a = pylab.Circle((0,11), radius=6,color = "w", alpha=.2,clip_on=True)
    circle11 = pylab.Circle((0,11), radius=16, alpha=.4)
    circle12 = pylab.Circle((0,5.5), radius=8, alpha=.4)
    a = np.array((x,y))
    b = np.array((m,n))
    dist = np.linalg.norm(a-b)
    print(dist)

# %%
ax = []
ax.append(pylab.Circle((5.5,0), radius=16, alpha=.4))
ax[0].center

# %%
ax[0].center.pat
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-790985a13ade> in <module>()
# ----> 1 ax[0].center-1
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'int'

# %%
eucl(10,10)
# Out:
# 10.9658560997

# %%
eucl = [12][12]
eucl[0][0] = x
eucl[0][1] = y
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-9838e637aab2> in <module>()
# ----> 1 eucl = [12][12]
#       2 eucl[0][0] = x
#       3 eucl[0][1] = y
#
# IndexError: list index out of range

# %%
def dist(x,y):
    eucl = []

# %%
pat = []
pat.append(circle1)
pat.append(circle2)
pat.append(circle3)
pat.append(circle4)
pat.append(circle5)
pat.append(circle6)
pat.append(circle7)
pat.append(circle8)
pat.append(circle9)
pat.append(circle10)
pat.append(circle11)
pat.append(circle12)
pat.append(circle1a)
pat.append(circle4a)
pat.append(circle3a)
pat.append(circle5a)
pat.append(circle7a)
pat.append(circle8a)

# %%
# plt.scatter(pat[0][0].get_path())
# plt.show()
i=0
while(i<12):
    contain3 = pat[i].contains_point([201.26666667,   45.88363636])
    print (contain3)
    contain4 = pat[i].contains_point([14,14])
    print (contain4)
    i = i + 1
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
pat[0].get_verts()
# Out:
# array([[ 201.26666667,   45.88363636],
#        [ 204.17412503,   45.93184943],
#        [ 209.92027683,   46.50244248],
#        [ 215.54930347,   47.62770101],
#        [ 221.02275244,   49.29169749],
#        [ 226.30217122,   51.47850434],
#        [ 231.34910729,   54.17219403],
#        [ 236.12510814,   57.356839  ],
#        [ 240.59172126,   61.0165117 ],
#        [ 242.68169657,   63.03830343],
#        [ 244.7034883 ,   65.12827874],
#        [ 248.363161  ,   69.59489186],
#        [ 251.54780597,   74.37089271],
#        [ 254.24149566,   79.41782878],
#        [ 256.42830251,   84.69724756],
#        [ 258.09229899,   90.17069653],
#        [ 259.21755752,   95.79972317],
#        [ 259.78815057,  101.54587497],
#        [ 259.83636364,  104.45333333],
#        [ 259.78815057,  107.36079169],
#        [ 259.21755752,  113.1069435 ],
#        [ 258.09229899,  118.73597014],
#        [ 256.42830251,  124.20941911],
#        [ 254.24149566,  129.48883788],
# ...

# %%
Path[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-5dabf9eb18c1> in <module>()
# ----> 1 Path[1]
#
# NameError: name 'Path' is not defined

# %%
obj('circle1').center
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-416726b8069f> in <module>()
# ----> 1 obj('circle1').center
#
# NameError: name 'obj' is not defined
