# %%
import pandas as pd

# %%
full_data = pd.read_csv("150.txt", header = None)
full_data.drop(full_data.index, inplace=True)

# %%
full_data.head()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
data_distance = []
i = 0
while i < 1500:
    i = i+150
    data_distance.append(i)

# %%
full_data.columns = [str(x) for x in full_data.columns]
full_data.drop(['2','3'],axis=1)
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
for i in data_distance:
    file_name = str(i) + ".txt"
    df = pd.read_csv(file_name, header = None)
    df_new = df
    df_new[0] = df[0].round(2)
    df_new[1] = i
    df_new.columns = [str(x) for x in df_new.columns]
    df_new = df_new.drop(['2','3'],axis=1)
    df_new.drop(df.index[:50], inplace=True)
    frames = [df_new, full_data]
    full_data = pd.concat(frames)

# %%
full_data.head()
# Out:
#           0       1   2   3
# 50  1486.92  1500.0 NaN NaN
# 51  1486.74  1500.0 NaN NaN
# 52  1486.66  1500.0 NaN NaN
# 53  1486.58  1500.0 NaN NaN
# 54  1486.43  1500.0 NaN NaN

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
full_data
# Out:
#             0       1   2   3
# 50    1486.92  1500.0 NaN NaN
# 51    1486.74  1500.0 NaN NaN
# 52    1486.66  1500.0 NaN NaN
# 53    1486.58  1500.0 NaN NaN
# 54    1486.43  1500.0 NaN NaN
# 55    1486.33  1500.0 NaN NaN
# 56    1486.34  1500.0 NaN NaN
# 57    1486.32  1500.0 NaN NaN
# 58    1486.37  1500.0 NaN NaN
# 59    1486.44  1500.0 NaN NaN
# 60    1486.43  1500.0 NaN NaN
# 61    1486.43  1500.0 NaN NaN
# 62    1486.33  1500.0 NaN NaN
# 63    1486.40  1500.0 NaN NaN
# 64    1486.36  1500.0 NaN NaN
# 65    1486.36  1500.0 NaN NaN
# 66    1486.30  1500.0 NaN NaN
# 67    1486.30  1500.0 NaN NaN
# 68    1486.23  1500.0 NaN NaN
# 69    1486.15  1500.0 NaN NaN
# 70    1486.15  1500.0 NaN NaN
# 71    1486.15  1500.0 NaN NaN
# 72    1486.15  1500.0 NaN NaN
# 73    1486.05  1500.0 NaN NaN
# 74    1486.08  1500.0 NaN NaN
# 75    1486.07  1500.0 NaN NaN
# 76    1486.09  1500.0 NaN NaN
# 77    1486.18  1500.0 NaN NaN
# 78    1486.25  1500.0 NaN NaN
# 79    1486.23  1500.0 NaN NaN
# ...       ...     ...  ..  ..
# 1762   164.99   150.0 NaN NaN
# 1763   165.07   150.0 NaN NaN
# 1764   165.16   150.0 NaN NaN
# 1765   165.24   150.0 NaN NaN
# 1766   165.24   150.0 NaN NaN
# 1767   165.30   150.0 NaN NaN
# 1768   165.38   150.0 NaN NaN
# 1769   165.38   150.0 NaN NaN
# 1770   165.41   150.0 NaN NaN
# 1771   165.41   150.0 NaN NaN
# 1772   165.41   150.0 NaN NaN
# 1773   165.41   150.0 NaN NaN
# 1774   165.40   150.0 NaN NaN
# 1775   165.40   150.0 NaN NaN
# 1776   165.34   150.0 NaN NaN
# 1777   165.34   150.0 NaN NaN
# 1778   165.34   150.0 NaN NaN
# 1779   165.34   150.0 NaN NaN
# 1780   165.26   150.0 NaN NaN
# 1781   165.17   150.0 NaN NaN
# 1782   165.09   150.0 NaN NaN
# 1783   165.00   150.0 NaN NaN
# 1784   164.92   150.0 NaN NaN
# 1785   164.84   150.0 NaN NaN
# 1786   164.80   150.0 NaN NaN
# 1787   164.72   150.0 NaN NaN
# 1788   164.64   150.0 NaN NaN
# 1789   164.56   150.0 NaN NaN
# 1790   164.56   150.0 NaN NaN
# 1791   164.66   150.0 NaN NaN
#
# [14715 rows x 4 columns]

# %%
a = np.array(full_data['1'])

# %%
b = np.array(full_data['0'])

# %%
plt.scatter(a,b,color = 'r')
plt.show()

# %%
a
# Out:
# array([ 1500.,  1500.,  1500., ...,   150.,   150.,   150.])
